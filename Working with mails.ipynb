# %%
import smtplib
from PIL import Image
import imaplib

# %%
smtp_object=smtplib.SMTP('smtp.gmail.com',587)

# %%
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [49.204.178.165]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
 smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
import getpass

# %%
email=getpass.getpass('please enter ur gmail')
password=getpass.getpass('please enter ur passwrod')
smtp_object.login(email,password)
# Out:
# please enter ur gmail········
# please enter ur passwrod········
# (235, b'2.7.0 Accepted')

# %%
from_address=email
recieving='zaynulaabideen23@gmail.com'
subject=input('enter your subject')
message=input('enetr your message')
msg='Subject: '+subject+'\n'+message
smtp_object.sendmail(from_address,recieving,msg)
# Out:
# enter your subjectpython gmailsending test
# enetr your messagehello me
# {}

# %%
smtp_object.quit()
# Out:
# (221,
#  b'2.0.0 closing connection g8-20020a170902740800b001ac82e8491csm16993966pll.282 - gsmtp')

# %%
#recieving mails in python

# %%
_=Image.open('python keywrods.png')
_
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1547x876 at 0x24FD4727AF0>

# %%
M=imaplib.IMAP4_SSL('imap.gmail.com')

# %%
import getpass

# %%
email2=getpass.getpass('enter ur email')
password2=getpass.getpass('enter ur password')
# Out:
# enter ur email········
# enter ur password········

# %%
M.login(email2,password2)
# Out:
# ('OK', [b'zaynulaabideen23@gmail.com authenticated (Success)'])

# %%
M.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasNoChildren) "/" "Notes"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"',
#   b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"'])

# %%
M.select('inbox')
# Out:
# ('OK', [b'1215'])

# %%
typ , data=M.search(None,'SUBJECT "random puller"')

# %%
typ
# Out:
# 'OK'

# %%
data
# Out:
# [b'1215']

# %%
email_id=data[0]

# %%
result,emaildata=M.fetch(email_id,'(RFC822)')

# %%
emaildata
# Out:
# [(b'1213 (RFC822 {566}',
#   b'MIME-Version: 1.0\r\nDate: Wed, 17 May 2023 15:31:36 +0530\r\nMessage-ID: <CA+LiiUNT7GkV7ALZs2KtHk1Wb6ZVAPaoEYPARh4j=RqcgUn73A@mail.gmail.com>\r\nSubject: New test python\r\nFrom: Zaynul Aabideen <zaynulaabideen23@gmail.com>\r\nTo: Zaynul Aabideen <zaynulaabideen23@gmail.com>\r\nContent-Type: multipart/alternative; boundary="00000000000005144005fbe0c68f"\r\n\r\n--00000000000005144005fbe0c68f\r\nContent-Type: text/plain; charset="UTF-8"\r\n\r\n\r\n\r\n--00000000000005144005fbe0c68f\r\nContent-Type: text/html; charset="UTF-8"\r\n\r\n<div dir="ltr"><br></div>\r\n\r\n--00000000000005144005fbe0c68f--'),
#  b')']

# %%
import email

# %%
raw_email=emaildata[0][1]

# %%
raw_email_string=raw_email.decode('utf-8')

# %%
email_message=email.message_from_string(raw_email_string)

# %%
#check for text/html is a link is part ofthe mail 
for part in email_message.walk():
    if part.get_content_type()=='text/plain':
        body=part.get_payload(decode=True)
        print(body)
