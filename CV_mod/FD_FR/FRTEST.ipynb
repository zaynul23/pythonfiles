# %%
import onnxruntime as ort

print("Available providers:", ort.get_available_providers())
# Out:
# Available providers: ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']

# %%
import tensorrt as trt
import pycuda.driver as cuda
import pycuda.autoinit

print("TensorRT version:", trt.__version__)
print("CUDA Device Name:", cuda.Device(0).name())
print("CUDA Driver Version:", cuda.get_driver_version())
# Out:
# TensorRT version: 10.13.3.9
# CUDA Device Name: NVIDIA GeForce RTX 3060 Laptop GPU
# CUDA Driver Version: 13000

# %%
# Out:
# Path: d:\zaynu\Documents\pythonfiles\CV_mod\FD_FR\facegpu\lib\site-packages\typing_extensions.py
# Sentinel in module: False

# %%
import torch
from insightface.model_zoo.scrfd import SCRFD

# %%
from torch import __version__

# %%
from onnxruntime import __version__ as onnx_v

# %%
onnx_v
# Out:
# '1.23.2'

# %%
from tensorrt import __version__ as tenRT_V
tenRT_V
# Out:
# '10.13.3.9'

# %%
import torch.onnx
print(torch.onnx.export.__defaults__)
# Out:
# ((), None)

# %%
from insightface.model_zoo
