# %%
from PIL import Image

# %%
mac=Image.open('example.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.format
# Out:
# 'JPEG'

# %% [markdown]
#                                                             cropping

# %%
pencils=Image.open('pencils.jpg')

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
pencils.crop((0,0,500*1.15,1000*1.30))
# Out:
# <PIL.Image.Image image mode=RGB size=575x1300 at 0x1F1DFFB4250>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x1F1DC9EB040>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
a,b=mac.size

# %%
x=a*0.58

y=b*0.65

# %%
mac.crop((x-300,y,x,b))
# Out:
# <PIL.Image.Image image mode=RGB size=300x440 at 0x1F1DFFEF280>

# %%
computer=mac.crop((x-300,y,x,b))

# %%
mac.paste(im=computer,box=(0,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x1F1DC9EB040>

# %%
1000*1.5855210819411296
# Out:
# 1585.5210819411295

# %%
mac.resize((100,158))
# Out:
# <PIL.Image.Image image mode=RGB size=100x158 at 0x1F1F8DB4D30>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x1F1DC9EB040>

# %% [markdown]
#                                                     colour transparency

# %%
red=Image.open('red_color.jpg')

# %%
blue=Image.open('blue_color.jpg')

# %%
blue_test=blue

# %%
red.putalpha(100)

# %%
blue.putalpha(100)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x1F1DFFB4BE0>

# %%
blue.paste(red,(0,0),red)

# %%
blue
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x1F1F8EE9FD0>

# %% [markdown]
#                                                         homework

# %%
data=Image.open('word_matrix.png')

# %%
data.size
# Out:
# (1015, 559)

# %%
mask=Image.open('mask.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x1F1FA4B5D30>

# %%
mask2=mask.resize(data.size)

# %%
mask2.putalpha(150)

# %%
data.paste(mask2,(0,0),mask2)

# %%
data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x1F1FB44A6A0>

# %% [markdown]
#                             answer=great work with images you are the best
