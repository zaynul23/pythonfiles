# %%
                                                    #creating card game war

# %%
#card class 
#it should underestand  the suit(diamonds,hearts,clubs,etc),Rank,Value

#DECK cLAss


#player

# %%
#to use when making random cards
import random
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.values=values[rank.title()]
        
    def __str__(self):
        return self.rank+' of '+self.suit

# %%
                                                     #creating DECK class

# %%
class Deck:
    
    
    def __init__(self):
        self.allcards=[]
        
        for suit in suits:
            for rank in ranks:
                created_card=Card(suit,rank)
                self.allcards.append(created_card)
    
    def shuffler(self):
        random.shuffle(self.allcards)
        
    def card_pull(self):
            
        return self.allcards.pop()

# %%
                                                            #player
class Player:
    def __init__(self,name):
        self.name=name
        self.player_deck=[]
    
    def remove_card(self):
        return self.player_deck.pop(0)
    
    
    def add_card(self,new_cards):
        if type(new_cards)==type([]):
            self.player_deck.extend(new_cards)
        else:
            self.player_deck.append(new_cards) 
    
    
    def __str__(self):
        return(f'hello {self.name} your deck has {len(self.player_deck)} cards ')
    
    def __len__(self):
        return len(self.player_deck)

# %%
                                                    #The main code

# %%
rounds=0
game_on=True
p1=Player("Zaynul")
p2=Player("robot")
new_deck=Deck()
gamecardlen="acacc"
new_deck.shuffler()
while gamecardlen not in range(2,9):
    gamecardlen=int(input('please enter how many cards both players should put down during war(2-8): '))
    if gamecardlen not in range(2,9):
        print('please enter something between 1 and 9')

for i in range(26):
    p1.add_card(new_deck.card_pull())
    p2.add_card(new_deck.card_pull())

while game_on:
    #win check
    rounds+=1
    print(f'the number of rounds done is {rounds}')
    if len(p1)==0:
        print(p1,f"\n {p2.name} has won the game")
        game_on=False
        break
    elif len(p2)==0:
        print(p2,f"\n {p1.name} has won the game")
        game_on=False
        break
    
    #both remopving a card and chcking whats better
    p1_removal=p1.remove_card()
    p2_removal=p2.remove_card()
    
    #adding both cards to who ever put higher value card
    if p1_removal.values > p2_removal.values:
        print(f"{p1.name}'s {p1_removal} has a greater valuer then {p2.name}'s {p2_removal}")
        p1.add_card(p1_removal)
        p1.add_card(p2_removal)
    
    elif p2_removal.values > p1_removal.values:
        print(f"{p2.name}'s {p2_removal} has a greater valuer then {p1.name}'s {p1_removal}")
        p2.add_card(p2_removal)
        p2.add_card(p1_removal)
        
        #in case both cards are of same value war modoe is turned on and war_deck list is made to compare to eachother    
    elif p2_removal.values == p1_removal.values:
        war_mode=True
        p1_wardeck=[p1_removal]
        p2_wardeck=[p2_removal]
        
        while war_mode:
            #win check
            if len(p1)==0:
                print(p1,f"\n {p2.name} has won the game")
                game_on=False
                war_mode=False
                break
            elif len(p2)==0:
                print(p2,f"\n {p1.name} has won the game")
                game_on=False
                war_mode=False
                break
           
            #adding cards for war
            if len(p1)<gamecardlen:
                for i in range(len(p1)):
                    p1_wardeck.append(p1.remove_card())
                    p2_wardeck.append(p2.remove_card())
            elif len(p2)<gamecardlen:
                for i in range(len(p2)):
                    p2_wardeck.append(p2.remove_card())
                    p1_wardeck.append(p1.remove_card())
            
            else:
                for i in range(gamecardlen):
                    p1_wardeck.append(p1.remove_card())
                    p2_wardeck.append(p2.remove_card())
                

                
            
                
            p1_removal_2=p1_wardeck[-1]
            p2_removal_2=p2_wardeck[-1]
            
            if p1_removal_2.values > p2_removal_2.values:
                print(f"{p1.name}'s {p1_removal_2} has a greater valuer then {p2.name}'s {p2_removal_2}")
                
                
                p1.add_card(p1_wardeck[::-1])
                p1.add_card(p2_wardeck[::-1])
                war_mode=False
                break
                
            elif p2_removal_2.values > p1_removal_2.values:
                print(f"{p2.name}'s {p2_removal_2} has a greater valuer then {p1.name}'s {p1_removal_2}")
                
                p2.add_card(p2_wardeck[::-1])
                p2.add_card(p1_wardeck[::-1])
                war_mode=False
                break
                
            elif p2_removal.values == p1_removal.values:
                pass

# %%
                                                #THE ACTULAL MINESTONE PROJECT STARTS

# %%
#to use when making random cards
import random
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':10, 'Queen':10, 'King':10, 'Ace':11}
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.values=values[rank.title()]
        
    def __str__(self):
        return self.rank+' of '+self.suit

# %%
class Deck:
    
    
    def __init__(self):
        self.allcards=[]
        
        for suit in suits:
            for rank in ranks:
                created_card=Card(suit,rank)
                self.allcards.append(created_card)
    
    def shuffler(self):
        random.shuffle(self.allcards)
        
    def card_pull(self):
            
        return self.allcards.pop()

# %%
                                                            #player
class Player:
    def __init__(self,name):
        self.name=name
        self.player_deck=[]
    
    
    
    def add_card(self,new_cards):
        if type(new_cards)==type([]):
            self.player_deck.extend(new_cards)
        else:
            self.player_deck.append(new_cards) 
    
    
    def __str__(self):
        a=[i.values for i in self.player_deck]
        return(f'hello {self.name} your deck has value of {sum(a)} cards ')
    
    def totalsum(self):
        a=[i.values for i in self.player_deck]
        return sum(a)
    
    def losecheck(self):
        a=[i.values for i in self.player_deck]
        if self.totalsum()>21:
            if 11 in a:
                return ((self.totalsum()-10) >21)
            else:
                return True
        else:
            return False
        
    def wincheck(self):
        a=[i.values for i in self.player_deck]
        if self.totalsum()==21:
            return True
        elif self.totalsum()==31:
            if 11 in a:
                return True
        else:
            return False
        
    def hit_stay(self,deck):
        a=[i.values for i in self.player_deck]
        p1choice='dw'
        while p1choice.capitalize() not in ['Hit',"Stay"]:
            p1choice=input(f'{self.name}, would you like to Hit or Stay ')
            if p1choice.capitalize() not in ['Hit',"Stay"]:
                print('please enter a valid input')
            if p1choice.capitalize() == 'Hit':
                self.add_card(deck.card_pull())
                if 11 in a:
                    if self.totalsum() > 21:
                        
                        print(f'your total card value {self.totalsum()-10}, you have an Ace in your deck')
                    else:
                        print(f'your total card value {self.totalsum()}, you have an Ace in your deck')
                else:
                    print(f'your total card value {self.totalsum()}')
            
            elif p1choice.capitalize() == 'Stay':
                return "Stay"

# %%
class Bank: 
    def __init__(self,name):
    
        self.name=name
        self.balance=0
        self.betting=0
    
    def debited(self,amount):
        if withdrawamnt>self.balance:
            return (f'you do not have sufficient funds balance \nCurrent balance: {self.balance}')
        self.balance-=amount
        return amount
    def deposit(self,deposit):
        self.balance+=deposit
    
    def bettingmethod(self,amount):
        self.betting+=amount
        self.balance-=amount

# %%
def replay():
    replaying='qw'
    while replaying.capitalize() not in ['Y','N']:
        replaying=input('would you like to play again (Y/N): ')
        if replaying.capitalize() not in ['Y','N']:
            print('please enetr valid answer')
    if replaying.capitalize()=='Y':
        return True
    else:
        return False
    
def banking(p1bank,p2bank):
    for i in[p1bank,p2bank]:
        betamount=2**64
        while (type(betamount)!= type(1)) or (betamount > i.balance) :
            betamount=int(input(f'{i.name}, how much would you like to bet '))
            if type(betamount)!= type(1):
                print('please enter a valid input')
            elif betamount > i.balance:
                print(f'{i.name} you dont have enough balance to bet that much')
                ifrebetting='d'
                while ifrebetting.capitalize() not in ['Y','N']:
                    ifrebetting=input(f'{i.name},  would you like to add balance (Y/N): ')
                    if ifrebetting.capitalize() not in ['Y','N']:
                        print('please enter a valid input')
                if ifrebetting.capitalize()=='Y':
                    rebetting='dw'
                    while type(rebetting) != type(1):
                        rebetting=int(input(f'{i.name}, please enter how much you would like to deposit: '))
                        if type(rebetting) != type(1):
                            print('please enter a valid input')
                    i.deposit(rebetting)
                    betamount=2**64
        i.bettingmethod(betamount)

        


p1name=1
while type(p1name) != type(' '):
    p1name=input(f'Player 1 whats your name')
p2name=1
while type(p2name) != type(' '):
    p2name=input(f'Player 2 whats your name')
    

p1=Player(p1name)
p2=Player(p2name)
p1bank=Bank(p1name)
p2bank=Bank(p2name)
new_deck=Deck()
new_deck.shuffler()
gameon=True 

for i in[p1bank,p2bank]:
    bankdeposit='wff'
    while type(bankdeposit)!=type(1) :
        bankdeposit=int(input(f'{i.name}, please enter how much you would like to deposit: '))
        if type(bankdeposit)!=type(1):
            print('please enter a valid answer')
    i.deposit(bankdeposit)


banking(p1bank,p2bank)

while gameon:
    for i in[p1,p2]:
        if i.wincheck():
            print( f' {i.name} has won the game you cards value is {i.totalsum()}')
            if i.name==p1bank.name:
                p1bank.deposit(p2bank.betting)
                p1bank.deposit(p1bank.betting)
                p1bank.betting-=p1bank.betting
                p2bank.betting-=p2bank.betting
            else:
                p2bank.deposit(p1bank.betting)
                p2bank.deposit(p2bank.betting)
                p2bank.betting-=p2bank.betting
                p1bank.betting-=p1bank.betting
            gameon=False    
            
        if i.losecheck():
            print( f' {i.name} has bust, your cards value is {i.totalsum()}')
            if i.name==p1bank.name:
                p2bank.deposit(p1bank.betting)
                p2bank.deposit(p2bank.betting)
                p2bank.betting-=p2bank.betting
                p1bank.betting-=p1bank.betting
            else:
                p1bank.deposit(p2bank.betting)
                p1bank.deposit(p1bank.betting)
                p1bank.betting-=p1bank.betting
                p2bank.betting-=p2bank.betting
            gameon=False    
            
    if p1.losecheck() or p1.wincheck() or  p2.losecheck() or p2.wincheck():
        gameon=False
    
    while gameon:
        if p1.losecheck() or p1.wincheck() or  p2.losecheck() or p2.wincheck():
            break
        if p1.hit_stay(new_deck)=='Stay':
            break
        
    
        
    while gameon:
        if p1.losecheck() or p1.wincheck() or  p2.losecheck() or p2.wincheck():
            break
        if p2.hit_stay(new_deck)=='Stay':
            break

    if  gameon==False:
        if replay():
            p1=Player(p1name)
            p2=Player(p2name)
            new_deck=Deck()
            new_deck.shuffler()
            gameon=True 
            banking(p1bank,p2bank)
            
        else:
            pass
# Out:
# Player 1 whats your namez
# Player 2 whats your namer
# z, please enter how much you would like to deposit: 1000
# r, please enter how much you would like to deposit: 1000
# z, how much would you like to bet 500
# r, how much would you like to bet 500
# z, would you like to Hit or Stay hit
# your total card value 10
# z, would you like to Hit or Stay hit
# your total card value 17
# z, would you like to Hit or Stay stay
# r, would you like to Hit or Stay hit
# your total card value 2
# r, would you like to Hit or Stay hit
# your total card value 12
# r, would you like to Hit or Stay hit
# your total card value 20
# r, would you like to Hit or Stay hit
# your total card value 30
#  r has bust, your cards value is 30
# would you like to play again (Y/N): n
